# %% [markdown]
# <a href="https://colab.research.google.com/github/AmritGaur/pythonbyme/blob/main/Walmart_Hackathon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pytrends
# Out:
# Collecting pytrends
#   Downloading pytrends-4.9.2-py3-none-any.whl (15 kB)
# Requirement already satisfied: requests>=2.0 in /usr/local/lib/python3.10/dist-packages (from pytrends) (2.31.0)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.10/dist-packages (from pytrends) (1.5.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from pytrends) (4.9.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25->pytrends) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25->pytrends) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25->pytrends) (1.23.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0->pytrends) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0->pytrends) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0->pytrends) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0->pytrends) (2023.7.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=0.25->pytrends) (1.16.0)
# Installing collected packages: pytrends
# Successfully installed pytrends-4.9.2

# %%
from pytrends.request import TrendReq
pytrends = TrendReq(hl='en-US', tz=360)

# %%
trending_IN = pytrends.trending_searches(pn='india')

# %%
Tech_rtst_IN=pytrends.realtime_trending_searches(pn='IN',cat='t')
Bus_rtst_IN= pytrends.realtime_trending_searches(pn='IN',cat='b')
Enter_rtst_IN= pytrends.realtime_trending_searches(pn='IN',cat='e')
Health_rtst_IN = pytrends.realtime_trending_searches(pn='IN',cat='m')
Sports_rtst_IN = pytrends.realtime_trending_searches(pn='IN',cat='s')
All_rtst_IN = pytrends.realtime_trending_searches(pn='IN',cat='all')

# %%
Tech_entities = list(Tech_rtst_IN['entityNames'])
Bus_entities = list(Bus_rtst_IN['entityNames'])
Enter_entities = list(Enter_rtst_IN['entityNames'])
Health_entities = list(Health_rtst_IN['entityNames'])
Sports_entities = list(Sports_rtst_IN['entityNames'])
All_entities = list(All_rtst_IN['entityNames'])

# %%
def extract_unique(list1:list):
  distinct = set()

  for i in range(len(list1)):
    for j in range(len(list1[i])):
      distinct.add(list1[i][j])
  return distinct

# %%
def links_returning(name:str):
  name = name.strip(' ')
  return ('https://www.walmart.com/search?q='+name)

# %%
Tech_distinct_entities = extract_unique(Tech_entities) #done
Bus_distinct_entities = extract_unique(Bus_entities) #done
Enter_distinct_entities = extract_unique(Enter_entities) #done
Health_distinct_entities = extract_unique(Health_entities) #done
Sports_distinct_entities = extract_unique(Sports_entities) #done
All_distinct_entities = extract_unique(All_entities) #done

# %%
import spacy

# Load a pre-trained spaCy NER model
nlp = spacy.load("en_core_web_sm")

def extract_products_from_text_list(text_list):
    extracted_products = []

    for text in text_list:
        doc = nlp(text)
        for ent in doc.ents:
            if ent.label_ == "ORG" or ent.label_ == "PRODUCT":
                extracted_products.append(ent.text)

    return extracted_products

# Example list of text
text_list = Tech_distinct_entities

extracted_Tech_products = extract_products_from_text_list(text_list)
print("Extracted Products:", extracted_Tech_products)
# Out:
# Extracted Products: ['Larian Studios', 'Google Nest', 'Microsoft Corporation', 'Digital Government Regulatory Authority', 'Bungie Inc.', 'Huawei', 'Google Slides', 'FarmVille', 'Google', 'Rainbow Six Siege', 'Android', 'Copenhagen', 'NanoAvionics', 'Amazon', 'Alexa', 'Apple', 'Apple Watch', 'Intel', 'Mitsui & Co.', 'Smart TV', 'Yveltal', 'YouTube', 'MEMS', 'The Pokémon Company', 'Baldur', 'Tablet', 'LG Corp', 'European XFEL', 'State Space Corporation', 'Porsche', 'MediaTek', 'Blizzard Entertainment', 'Snapdragon', 'Harvard University', 'Super Smash Bros. Ultimate', 'Sony Corporation', 'Google Keep', 'FC', 'National Oceanic and Atmospheric Administration', 'Samsung Galaxy Watch', 'EA Sports', 'Telegram', 'Metabolic', 'NetherRealm Studios', 'Niantic, Inc.', 'Amazon Echo', 'Cytoskeleton', 'Google', 'Android', 'NASA', 'AMD Radeon RX Series', 'OSIRIS', 'Organoid', 'Neutron', 'Samsung', 'House', 'Rockstar Games', 'Sony', 'PlayStation', 'Nintendo', 'AMD', 'MacBook', 'Pokémon', 'FromSoftware Inc.', 'Apple Music', 'Google Photos', 'Google Analytics', 'Quantum', 'WhatsApp', 'Google Chrome', 'SLAC National Accelerator Laboratory', 'Macintosh', 'National Hockey League', 'Apple TV', 'PTron', 'Electron', 'Photosynthesis', 'Neutron', 'Drop', 'Oak Ridge National Laboratory', 'SIM', 'Pokémon GO']

# %%
import pandas as pd
Tech_df = pd.DataFrame(extracted_Tech_products,columns=['Name'])

# %%
Tech_df['Link'] = Tech_df['Name'].apply(links_returning)

# %%
Tech_df.head(20)
# Out:
#                                        Name  \
# 0                            Larian Studios
# 1                               Google Nest
# 2                     Microsoft Corporation
# 3   Digital Government Regulatory Authority
# 4                               Bungie Inc.
# 5                                    Huawei
# 6                             Google Slides
# 7                                 FarmVille
# 8                                    Google
# 9                         Rainbow Six Siege
# 10                                  Android
# 11                               Copenhagen
# 12                             NanoAvionics
# 13                                   Amazon
# 14                                    Alexa
# 15                                    Apple
# 16                              Apple Watch
# 17                                    Intel
# 18                             Mitsui & Co.
# 19                                 Smart TV
#
#                                                  Link
# 0     https://www.walmart.com/search?q=Larian Studios
# 1        https://www.walmart.com/search?q=Google Nest
# 2   https://www.walmart.com/search?q=Microsoft Cor...
# 3   https://www.walmart.com/search?q=Digital Gover...
# 4        https://www.walmart.com/search?q=Bungie Inc.
# 5             https://www.walmart.com/search?q=Huawei
# 6      https://www.walmart.com/search?q=Google Slides
# 7          https://www.walmart.com/search?q=FarmVille
# 8             https://www.walmart.com/search?q=Google
# 9   https://www.walmart.com/search?q=Rainbow Six S...
# 10           https://www.walmart.com/search?q=Android
# 11        https://www.walmart.com/search?q=Copenhagen
# 12      https://www.walmart.com/search?q=NanoAvionics
# 13            https://www.walmart.com/search?q=Amazon
# 14             https://www.walmart.com/search?q=Alexa
# 15             https://www.walmart.com/search?q=Apple
# 16       https://www.walmart.com/search?q=Apple Watch
# 17             https://www.walmart.com/search?q=Intel
# 18      https://www.walmart.com/search?q=Mitsui & Co.
# 19          https://www.walmart.com/search?q=Smart TV

# %%
Health_df = pd.DataFrame(Health_distinct_entities,columns=['Name'])

# %%
Health_df['Link'] = Health_df['Name'].apply(links_returning)

# %%
Health_df
# Out:
#                             Name  \
# 0                Cell Metabolism
# 1                    Blood Sugar
# 2           Renal cell carcinoma
# 3                   Dengue fever
# 4    Respiratory tract infection
# ..                           ...
# 391                   Immunology
# 392                 Hyperthermia
# 393            Allergic rhinitis
# 394               Chagas disease
# 395                    Hematuria
#
#                                                   Link
# 0     https://www.walmart.com/search?q=Cell Metabolism
# 1         https://www.walmart.com/search?q=Blood Sugar
# 2    https://www.walmart.com/search?q=Renal cell ca...
# 3        https://www.walmart.com/search?q=Dengue fever
# 4    https://www.walmart.com/search?q=Respiratory t...
# ..                                                 ...
# 391        https://www.walmart.com/search?q=Immunology
# 392      https://www.walmart.com/search?q=Hyperthermia
# 393  https://www.walmart.com/search?q=Allergic rhin...
# 394    https://www.walmart.com/search?q=Chagas disease
# 395         https://www.walmart.com/search?q=Hematuria
#
# [396 rows x 2 columns]

# %%
Enter_df = pd.DataFrame(Enter_distinct_entities,columns=['Name'])

# %%
Enter_df['Link'] = Enter_df['Name'].apply(links_returning)

# %%
print(Enter_df)
# Out:
#                        Name                                               Link
# 0             Saif Ali Khan     https://www.walmart.com/search?q=Saif Ali Khan
# 1                 Woodstock         https://www.walmart.com/search?q=Woodstock
# 2                    Injury            https://www.walmart.com/search?q=Injury
# 3    Beyoncé Knowles-Carter  https://www.walmart.com/search?q=Beyoncé Knowl...
# 4                 Billboard         https://www.walmart.com/search?q=Billboard
# ..                      ...                                                ...
# 371        Red Giant Movies  https://www.walmart.com/search?q=Red Giant Movies
# 372           Jaya Bachchan     https://www.walmart.com/search?q=Jaya Bachchan
# 373             Ryan Murphy       https://www.walmart.com/search?q=Ryan Murphy
# 374   The Lord of the Rings  https://www.walmart.com/search?q=The Lord of t...
# 375            Sarah Hyland      https://www.walmart.com/search?q=Sarah Hyland
#
# [376 rows x 2 columns]

# %%
import spacy

# Load a pre-trained spaCy NER model
nlp = spacy.load("en_core_web_sm")

def extract_products_from_text_list(text_list):
    extracted_products = []

    for text in text_list:
        doc = nlp(text)
        for ent in doc.ents:
            if ent.label_ == "NORP" or ent.label_ == "GPE":
              continue
            if ent.label_ == "ORG" or ent.label_ == "PRODUCT":
                extracted_products.append(ent.text)

    return extracted_products

# Example list of text
text_list = Sports_distinct_entities

extracted_Sports_products = extract_products_from_text_list(text_list)
print("Extracted Products:", extracted_Sports_products)
# Out:
# Extracted Products: ['SuperSport United F.C.', 'UEFA Champions League', 'Arizona Cardinals', 'Karnataka State Cricket Association', 'United States Tennis Association', 'Ultimate Fighting Championship', 'Mercedes-Benz', 'FIFA', "Women's Tennis Association", "FIFA Women's World Cup", 'Prada', 'Toronto Blue Jays', 'EFL League', 'Chicago Bulls', "FIFA Women's World Cup 2023", "ITF Men's World Tennis Tour", 'NFL', 'NBA', 'Red Bull Racing', 'Inter Milan', 'MLS', 'Wales Cricket Board', 'Texas A&M Aggies', 'Novak', 'Stanford Cardinal', 'Real Madrid CF', 'Portland Trail Blazers', 'Western & Southern Open', 'Charlotte Hornets', 'Philadelphia Union', 'FC Bayern Munich', 'Broncos', 'Eastern Conference', 'New York', 'Metro Bank', 'NFL', 'Preseason', 'MLB', 'Paris Saint-Germain F.C.', 'Italian Football Federation', 'Golden State Warriors', 'Pakistan Cricket Board', 'Maharaja Trophy', 'International Tennis Federation', 'IBM', 'EA Sports', 'Minor League Baseball', 'Seattle Supersonics', 'Royal London', 'Nike', 'Premier League', 'Somerset County Cricket Club', 'All India Tennis Association', 'Alibag', 'MLS Cup', 'SSC Napoli', 'Mercedes AMG Petronas F1 Team', 'Baltimore Orioles', 'Little League World Series', 'World Athletics', 'Andhra Cricket Association', "Fédération Internationale de l'Automobile", 'National Hockey League', 'D.C. United', 'Stanford University', 'Armed Forces (Special Powers', 'Kaizer Chiefs', 'Bruins Daily']

# %%
Sports_df = pd.DataFrame(Sports_distinct_entities,columns=['Name'])

# %%
Sports_df['Link'] = Sports_df['Name'].apply(links_returning)

# %%
Sports_df
# Out:
#                          Name  \
# 0              Inter Miami CF
# 1      SuperSport United F.C.
# 2    Klaksvíkar Ítróttarfelag
# 3       UEFA Champions League
# 4                 Luka Modrić
# ..                        ...
# 324              Al Hilal SFC
# 325             Olympic Games
# 326      José Luis Mendilibar
# 327                    Serbia
# 328      Ireland cricket team
#
#                                                   Link
# 0      https://www.walmart.com/search?q=Inter Miami CF
# 1    https://www.walmart.com/search?q=SuperSport Un...
# 2    https://www.walmart.com/search?q=Klaksvíkar Ít...
# 3    https://www.walmart.com/search?q=UEFA Champion...
# 4         https://www.walmart.com/search?q=Luka Modrić
# ..                                                 ...
# 324      https://www.walmart.com/search?q=Al Hilal SFC
# 325     https://www.walmart.com/search?q=Olympic Games
# 326  https://www.walmart.com/search?q=José Luis Men...
# 327            https://www.walmart.com/search?q=Serbia
# 328  https://www.walmart.com/search?q=Ireland crick...
#
# [329 rows x 2 columns]

# %%
All_distinct_entities
# Out:
# {'2023',
#  '2030',
#  'ASX',
#  'Abhishek Bachchan',
#  'Adam Silver',
#  'Akshardham',
#  'Alice Springs',
#  'Amber Heard',
#  'Amitabh Bachchan',
#  'Andhra Pradesh',
#  'Aptech',
#  'Armed Forces of Ukraine',
#  'Asset management',
#  "Australia women's national football team",
#  'BASF',
#  'BSE',
#  'BSE SENSEX',
#  'Basalt',
#  'Basketball',
#  'Battle royale game',
#  'Big E',
#  'Bindeshwar Pathak',
#  'Bochasanwasi Akshar Purushottam Swaminarayan Sanstha',
#  'Boxing',
#  'Boxing training',
#  'Bulgarian Military Industry Review',
#  'Bumble',
#  'Bushfires in Australia',
#  'Call of Duty',
#  'Canelo Álvarez',
#  'Carbon',
#  'Carbon dioxide',
#  'Cardiac arrest',
#  'Cervical cancer',
#  'Challenger 2',
#  'Charlotte Hornets',
#  'Chemical industry',
#  'Chief Executive Officer',
#  'Cliff',
#  'Cody Rhodes',
#  'Common stock',
#  'Computer forensics',
#  'Computers and information technology',
#  'Conservative Party',
#  'Copper',
#  'Cruise line',
#  'Cruise ship',
#  'Darren Kent',
#  'Digital',
#  'Digital evidence',
#  'Digital forensics',
#  'Diversity',
#  'Dmitry Bivol',
#  'Draft',
#  'Drug overdose',
#  'Earnings',
#  'Earth',
#  'Element Solutions',
#  'Essel Group',
#  'Expansion team',
#  'Fernando',
#  'Finance',
#  'Forecasting',
#  'Forensic science',
#  'Formaldehyde',
#  'Game of Thrones',
#  'Gold',
#  'Gong Seung-yeon',
#  'Guru',
#  'HDFC Bank',
#  'HDFC Life Insurance',
#  'Hexion',
#  'Hinduism',
#  'Hollywood Vampires',
#  'Hot Chili',
#  'Housing',
#  'Human papillomavirus infection',
#  'India',
#  'Industry',
#  'Inflation',
#  'Injury',
#  'Investment fund',
#  'John Cena',
#  'Johnny Depp',
#  'Johnson Matthey',
#  'José Luis Mendilibar',
#  'Jurassic Coast',
#  'Ka',
#  'Kaun Banega Crorepati',
#  'Kevin Owens',
#  'KeyBank',
#  'Kim Rae-won',
#  'Korean drama',
#  'Light machine gun',
#  'Magma',
#  'Mahant Swami Maharaj',
#  'Majuba Hill Copper Corp',
#  'Manchester City F.C.',
#  'Market research',
#  'Market segmentation',
#  'Michael Burry',
#  'Mineral',
#  'Mobile game',
#  'NBA',
#  'NIFTY 50',
#  'NSE',
#  'NYSE:ESI',
#  'NYSE:RWT',
#  'Naloxone',
#  'Nana Patekar',
#  'Nasdaq',
#  'New Jersey',
#  'New York Stock Exchange',
#  'Nordea',
#  'Northern Territory',
#  'Nowruz',
#  'Old Navy',
#  'Online shopping',
#  'Opioid overdose',
#  'Palatin Technologies, Inc.',
#  'Pallavi Joshi',
#  'Pap test',
#  'Papillomaviruses',
#  'Parsis',
#  'Paul Wight',
#  'Philadelphia',
#  'Potato',
#  'Prabhas',
#  'Princess Cruises',
#  'Professional wrestling',
#  'Public sector banks in India',
#  'Punit Goenka',
#  'R. Balki',
#  'Randy Orton',
#  'Real Estate',
#  'Real estate investment trust',
#  'Redwood Trust, Inc.',
#  'Rockfall',
#  'Roman Reigns',
#  'S&P 500',
#  'S&P Global Ratings',
#  'Saiyami Kher',
#  'Sami Zayn',
#  'Sanitation',
#  'Sapphire Princess',
#  'Seattle Supersonics',
#  'Securities and Exchange Board of India',
#  'Security',
#  'Sevilla FC',
#  'Shah Rukh Khan',
#  'Share',
#  'Share price',
#  'Son Ho-jun',
#  'South America',
#  'Soviet Union',
#  'Stock',
#  'Stock market',
#  'Subhash Chandra',
#  'Sulabh International',
#  'Supply chain',
#  'Supply chain security',
#  'Swaminarayan',
#  'TSE:STGO',
#  'Tank',
#  'Taz',
#  'The Big Short',
#  'The Lord of the Rings: The Fellowship of the Ring',
#  'Tory',
#  'U.S. Securities and Exchange Commission',
#  'UEFA Super Cup',
#  'Ukraine',
#  'Ukrainians',
#  'United Kingdom',
#  'United States Department of Energy',
#  'Urea',
#  'Urea-formaldehyde',
#  'Vaccine',
#  'Vangaveeti Mohana Ranga',
#  'Vangaveeti Radha Krishna',
#  'Vivek Agnihotri',
#  'Volcanic eruption',
#  'Volcano',
#  'WWE',
#  'WWE Superstars',
#  'West Bay',
#  'Wildfire',
#  'World Cup',
#  'WrestleMania',
#  'Zee',
#  'Zee Entertainment Enterprises',
#  'Zoroastrianism',
#  'a',
#  'മ',
#  'ൻ',
#  'ർ',
#  'ൽ'}

# %%
import spacy

# Load a pre-trained spaCy NER model
nlp = spacy.load("en_core_web_sm")
entity_tags = ["PERSON", "NORP", "FAC", "ORG", "GPE", "LOC", "PRODUCT", "EVENT", "WORK_OF_ART", "LAW", "LANGUAGE", "DATE", "TIME", "PERCENT", "MONEY", "QUANTITY", "ORDINAL", "CARDINAL"]

def extract_products_from_text_list(text_list):
    extracted_products = []

    for text in text_list:
        doc = nlp(text)
        for ent in doc.ents:
          if ent.label_ in entity_tags:
                extracted_products.append(ent.text)

    return extracted_products

# Example list of text
text_list = All_distinct_entities

extracted_All_products = extract_products_from_text_list(text_list)
print("Extracted Products:", extracted_All_products)
# Out:
# Extracted Products: ['Saiyami Kher', 'Digital', 'Armed Forces of Ukraine', 'Zee Entertainment Enterprises', 'Vangaveeti Radha Krishna', 'WrestleMania', 'TSE', 'HDFC Bank', 'NYSE', 'RWT', 'BSE', 'Jurassic Coast', 'Andhra', 'Vivek Agnihotri', 'Soviet Union', 'Amitabh Bachchan', 'John Cena', 'South America', 'Aptech', 'Digital', 'S&P Global Ratings', 'Gong Seung-yeon', 'Randy Orton', 'NYSE', 'ESI', 'Australia', 'Swaminarayan', 'Kevin Owens', '2', 'Johnson Matthey', 'HDFC Life Insurance', 'Redwood Trust', 'U.S. Securities and Exchange Commission', 'R. Balki', 'Majuba Hill Copper Corp', 'Charlotte Hornets', 'NIFTY', 'Earth', 'Old Navy', 'New Jersey', 'Securities and Exchange Board of India', 'Seattle Supersonics', 'Digital', 'Basalt', 'Bumble', 'United Kingdom', 'Australia', 'Pallavi Joshi', 'Adam Silver', 'Ukrainians', 'Michael Burry', 'West Bay', 'United States Department of Energy', 'Korean', 'World Cup', 'Manchester City', 'F.C.', 'Guru', 'India', 'New York Stock Exchange', 'Darren Kent', 'Dmitry Bivol', 'Bochasanwasi', 'Akshar', 'Swaminarayan Sanstha', 'UEFA Super Cup', 'Cardiac', 'Ukraine', 'BSE', 'Nana Patekar', 'Conservative Party', 'BASF', 'Hollywood Vampires', 'Ho-jun', 'WWE', 'KeyBank', 'Chandra', 'Philadelphia', 'Palatin Technologies, Inc.', 'Sami Zayn', 'ASX', 'Magma', '2023', '2030', 'India', 'Cody Rhodes', 'Wildfire', 'Paul Wight', 'Vangaveeti Mohana', 'Kim Rae-won', 'Vaccine', 'Shah Rukh Khan', 'Essel Group', 'Thrones', 'Roman Reigns', 'NBA', 'Swami Maharaj', 'Nowruz', 'Canelo Álvarez', 'Abhishek Bachchan', 'Kaun Banega Crorepati', 'Alice Springs', 'Johnny', 'Northern Territory', 'José Luis Mendilibar', 'Bulgarian Military Industry Review', 'Bindeshwar Pathak']

# %%
All_df = pd.DataFrame(All_distinct_entities,columns=['Name'])

# %%
All_df['Link'] = All_df['Name'].apply(links_returning)

# %%
All_df
# Out:
#                                    Name  \
# 0                      Forensic science
# 1                          Saiyami Kher
# 2                    Battle royale game
# 3                      Digital evidence
# 4               Armed Forces of Ukraine
# ..                                  ...
# 191  Bulgarian Military Industry Review
# 192                            Hinduism
# 193                          Akshardham
# 194                   Bindeshwar Pathak
# 195                           Diversity
#
#                                                   Link
# 0    https://www.walmart.com/search?q=Forensic science
# 1        https://www.walmart.com/search?q=Saiyami Kher
# 2    https://www.walmart.com/search?q=Battle royale...
# 3    https://www.walmart.com/search?q=Digital evidence
# 4    https://www.walmart.com/search?q=Armed Forces ...
# ..                                                 ...
# 191  https://www.walmart.com/search?q=Bulgarian Mil...
# 192          https://www.walmart.com/search?q=Hinduism
# 193        https://www.walmart.com/search?q=Akshardham
# 194  https://www.walmart.com/search?q=Bindeshwar Pa...
# 195         https://www.walmart.com/search?q=Diversity
#
# [196 rows x 2 columns]

# %%
import spacy

# Load a pre-trained spaCy NER model
nlp = spacy.load("en_core_web_sm")
entity_tags = ["PERSON", "ORG", "GPE", "LOC", "PRODUCT", "EVENT", "WORK_OF_ART", "LAW", "LANGUAGE", "ORDINAL", "CARDINAL"]

def extract_products_from_text_list(text_list):
    extracted_products = []

    for text in text_list:
        doc = nlp(text)
        for ent in doc.ents:
          if ent.label_ in entity_tags:
                extracted_products.append(ent.text)

    return extracted_products

# Example list of text
text_list = Bus_distinct_entities

extracted_Bus_products = extract_products_from_text_list(text_list)
print("Extracted Products:", extracted_Bus_products)
# Out:
# Extracted Products: ['Digital', 'BP', 'BPCL', 'Zee Entertainment Enterprises', 'NYSE', 'RWT', 'ITC', 'BSE', 'Digital', 'S&P Global Ratings', 'Toyota', 'TSE', 'NYSE', 'BP', 'Johnson Matthey', 'Redwood Trust', 'IDEA', 'Spain', 'Taylor Devices, Inc.', 'Cision PR Newswire', 'NYSE', 'AJX', 'Adani Ports & SEZ', 'NIFTY', 'Old Navy', 'Securities and Exchange Board of India', 'Digital', 'Bumble', 'Bharat Petroleum', 'United Kingdom', 'NYSE', 'TPR', 'GlaxoSmithKline Pharmaceuticals', 'Michael Burry', 'New York Stock Exchange', 'Dividend', 'BSE', 'Conservative Party', 'BASF', 'ITC Limited', 'Gautam Adani', 'TSX', 'KeyBank', 'Chandra', 'Palatin Technologies, Inc.', 'India', 'Essel Group', 'Royal Bank of Canada', 'Park Lawn Corporation']

# %%
Bus_df = pd.DataFrame(extracted_Bus_products,columns=['Name'])

# %%
Bus_df['Link'] = Bus_df['Name'].apply(links_returning)

# %%
Bus_df
# Out:
#                                       Name  \
# 0                                  Digital
# 1                                       BP
# 2                                     BPCL
# 3            Zee Entertainment Enterprises
# 4                                     NYSE
# 5                                      RWT
# 6                                      ITC
# 7                                      BSE
# 8                                  Digital
# 9                       S&P Global Ratings
# 10                                  Toyota
# 11                                     TSE
# 12                                    NYSE
# 13                                      BP
# 14                         Johnson Matthey
# 15                           Redwood Trust
# 16                                    IDEA
# 17                                   Spain
# 18                    Taylor Devices, Inc.
# 19                      Cision PR Newswire
# 20                                    NYSE
# 21                                     AJX
# 22                       Adani Ports & SEZ
# 23                                   NIFTY
# 24                                Old Navy
# 25  Securities and Exchange Board of India
# 26                                 Digital
# 27                                  Bumble
# 28                        Bharat Petroleum
# 29                          United Kingdom
# 30                                    NYSE
# 31                                     TPR
# 32         GlaxoSmithKline Pharmaceuticals
# 33                           Michael Burry
# 34                 New York Stock Exchange
# 35                                Dividend
# 36                                     BSE
# 37                      Conservative Party
# 38                                    BASF
# 39                             ITC Limited
# 40                            Gautam Adani
# 41                                     TSX
# 42                                 KeyBank
# 43                                 Chandra
# 44              Palatin Technologies, Inc.
# 45                                   India
# 46                             Essel Group
# 47                    Royal Bank of Canada
# 48                   Park Lawn Corporation
#
#                                                  Link
# 0            https://www.walmart.com/search?q=Digital
# 1                 https://www.walmart.com/search?q=BP
# 2               https://www.walmart.com/search?q=BPCL
# 3   https://www.walmart.com/search?q=Zee Entertain...
# 4               https://www.walmart.com/search?q=NYSE
# 5                https://www.walmart.com/search?q=RWT
# 6                https://www.walmart.com/search?q=ITC
# 7                https://www.walmart.com/search?q=BSE
# 8            https://www.walmart.com/search?q=Digital
# 9   https://www.walmart.com/search?q=S&P Global Ra...
# 10            https://www.walmart.com/search?q=Toyota
# 11               https://www.walmart.com/search?q=TSE
# 12              https://www.walmart.com/search?q=NYSE
# 13                https://www.walmart.com/search?q=BP
# 14   https://www.walmart.com/search?q=Johnson Matthey
# 15     https://www.walmart.com/search?q=Redwood Trust
# 16              https://www.walmart.com/search?q=IDEA
# 17             https://www.walmart.com/search?q=Spain
# 18  https://www.walmart.com/search?q=Taylor Device...
# 19  https://www.walmart.com/search?q=Cision PR New...
# 20              https://www.walmart.com/search?q=NYSE
# 21               https://www.walmart.com/search?q=AJX
# 22  https://www.walmart.com/search?q=Adani Ports &...
# 23             https://www.walmart.com/search?q=NIFTY
# 24          https://www.walmart.com/search?q=Old Navy
# 25  https://www.walmart.com/search?q=Securities an...
# 26           https://www.walmart.com/search?q=Digital
# 27            https://www.walmart.com/search?q=Bumble
# 28  https://www.walmart.com/search?q=Bharat Petroleum
# 29    https://www.walmart.com/search?q=United Kingdom
# 30              https://www.walmart.com/search?q=NYSE
# 31               https://www.walmart.com/search?q=TPR
# 32  https://www.walmart.com/search?q=GlaxoSmithKli...
# 33     https://www.walmart.com/search?q=Michael Burry
# 34  https://www.walmart.com/search?q=New York Stoc...
# 35          https://www.walmart.com/search?q=Dividend
# 36               https://www.walmart.com/search?q=BSE
# 37  https://www.walmart.com/search?q=Conservative ...
# 38              https://www.walmart.com/search?q=BASF
# 39       https://www.walmart.com/search?q=ITC Limited
# 40      https://www.walmart.com/search?q=Gautam Adani
# 41               https://www.walmart.com/search?q=TSX
# 42           https://www.walmart.com/search?q=KeyBank
# 43           https://www.walmart.com/search?q=Chandra
# 44  https://www.walmart.com/search?q=Palatin Techn...
# 45             https://www.walmart.com/search?q=India
# 46       https://www.walmart.com/search?q=Essel Group
# 47  https://www.walmart.com/search?q=Royal Bank of...
# 48  https://www.walmart.com/search?q=Park Lawn Cor...

# %%
Tech_df.to_html()
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Name</th>\n      <th>Link</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>Larian Studios</td>\n      <td>https://www.walmart.com/search?q=Larian Studios</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>Google Nest</td>\n      <td>https://www.walmart.com/search?q=Google Nest</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>Microsoft Corporation</td>\n      <td>https://www.walmart.com/search?q=Microsoft Corporation</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>Digital Government Regulatory Authority</td>\n      <td>https://www.walmart.com/search?q=Digital Government Regulatory Authority</td>\n    </tr>\n    <tr>\n      <th>4</th>\n      <td>Bungie Inc.</td>\n      <td>https://www.walmart.com/search?q=Bungie Inc.</td>\n    </tr>\n    <tr>\n      <th>5</th>\n      <td>Huawei</td>\n      <td>https://www.walmart.com/search?q=Huawei</td>\n    </tr>\n    <tr>\n      <th>6</th>\n      <td>Google Slides</td>\n      <td>https://www.walmart.com/search?q=Google Slides</td>\n    </tr>\n    <tr>\n      <th>7</th>\n      <td>FarmVille</td>\n      <td>https://www.walmart.com/search?q=FarmVille</td>\n    </tr>\n    <tr>\n      <th>8</th>\n      <td>Google</td>\n      <td>https://www.walmart.com/search?q=Google</td>\n    </tr>\n    <tr>\n      <th>9</th>\n      <td>Rainbow Six Siege</td>\n      <td>https://www.walmart.com/search?q=Rainbow Six Siege</td>\n    </tr>\n    <tr>\n      <th>10</th>\n      <td>Android</td>\n      <td>https://www.walmart.com/search?q=Android</td>\n    </tr>\n    <tr>\n      <th>11</th>\n      <td>Copenhagen</td>\n      <td>https://www.walmart.com/search?q=Copenhagen</td>\n    </tr>\n    <tr>\n      <th>12</th>\n      <td>NanoAvionics</td>\n      <td>https://www.walmart.com/search?q=NanoAvionics</td>\n    </tr>\n    <tr>\n      <th>13</th>\n      <td>Amazon</td>\n      <td>https://www.walmart.com/search?q=Amazon</td>\n    </tr>\n    <tr>\n      <th>14</th>\n      <td>Alexa</td>\n      <td>https://www.walmart.com/search?q=Alexa</td>\n    </tr>\n    <tr>\n      <th>15</th>\n      <td>Apple</td>\n      <td>https://www.walmart.com/search?q=Apple</td>\n    </tr>\n    <tr>\n      <th>16</th>\n      <td>Apple Watch</td>\n      <td>https://www.walmart.com/search?q=Apple Watch</td>\n    </tr>\n    <tr>\n      <th>17</th>\n      <td>Intel</td>\n      <td>https://www.walmart.com/search?q=Intel</td>\n    </tr>\n    <tr>\n      <th>18</th>\n      <td>Mitsui &amp; Co.</td>\n      <td>https://www.walmart.com/search?q=Mitsui &amp; Co.</td>\n    </tr>\n    <tr>\n      <th>19</th>\n      <td>Smart TV</td>\n      <td>https://www.walmart.com/search?q=Smart TV</td>\n    </tr>\n    <tr>\n      <th>20</th>\n      <td>Yveltal</td>\n      <td>https://www.walmart.com/search?q=Yveltal</td>\n    </tr>\n    <tr>\n      <th>21</th>\n      <td>YouTube</td>\n      <td>https://www.walmart.com/search?q=YouTube</td>\n    </tr>\n    <tr>\n      <th>22</th>\n      <td>MEMS</td>\n      <td>https://www.walmart.com/search?q=MEMS</td>\n    </tr>\n    <tr>\n      <th>23</th>\n      <td>The Pokémon Company</td>\n      <td>https://www.walmart.com/search?q=The Pokémon Company</td>\n    </tr>\n    <tr>\n      <th>24</th>\n      <td>Baldur</td>\n      <td>https://www.walmart.com/search?q=Baldur</td>\n    </tr>\n    <tr>\n      <th>25</th>\n      <td>Tablet</td>\n      <td>https://www.walmart.com/search?q=Tablet</td>\n    </tr>\n    <tr>\n      <th>26</th>\n      <td>LG Corp</td>\n      <td>https://www.walmart.com/search?q=LG Corp</td>\n    </tr>\n    <tr>\n      <th>27</th>\n      <td>European XFEL</td>\n      <td>https://www.walmart.com/search?q=European XFEL</td>\n    </tr>\n    <tr>\n      <th>28</th>\n      <td>State Space Corporation</td>\n      <td>https://www.walmart.com/search?q=State Space Corporation</td>\n    </tr>\n    <tr>\n      <th>29</th>\n      <td>Porsche</td>\n      <td>https://www.walm ...
